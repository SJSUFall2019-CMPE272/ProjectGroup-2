# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('Book1.xlsx', sheet_name='Table W-1',index_col = 0)

# %%
df = df.dropna(how = 'all').fillna(0.0).astype(int)

# %%
outside = ['Kitchen Remodels','Kitchen Remodels','Bath Remodels','Bath Remodels','Room Additions','Room Additions','Room Additions','Room Additions','Outside Attachments','Outside Attachments','Exterior','Exterior','Exterior','Exterior','Interior','Interior','Interior','Systems and Equipments','Systems and Equipments','Systems and Equipments','Systems and Equipments','Systems and Equipments','Disaster Repairs','Improvements to Yard','Total']

# %%
inside = ['Minor','Major','Minor','Major','Kitchen','Bath','Bedroom','Other','Porch, Deck or Terrace','Garage','Roofing','Siding','Windows or Doors','Chimney, Stairs or Other Exterior','Insulation','Carpeting, Flooring, Paneling or Ceiling Tiles', 'Other Major Improvements indoors', 'Internal Water Pipes', 'Plumbing Fixtures','Electrical System','HVAC', 'Appliances/Major Equipment', 'Disaster Repairs','Improvements to Lot or Yard', 'Total']

# %%
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df.reset_index(drop=True,inplace = True)

# %%
df
# Out:
#     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0         1670        1455        1178        1144        1282        1341
# 1          446         419         548         686         644         855
# 2         1787        1565        1444        1452        1489        1524
# 3          516         561         632         760         773         971
# 4          328         259          44          44          37          49
# 5          571         488         397         403         409         452
# 6          637         536         656         608         645         653
# 7         1420        1190        1425        1391        1409        1477
# 8         1188        1055        1130         968         889         923
# 9          223         167         233         213         213         202
# 10        2514        2836        3478        3405        2886        3490
# ...

# %%
df = pd.DataFrame(df.values,hier_index,[1995,1997,1999,2001,2003,2005,2007,2009,2011,2013,2015])

# %%
df= df.T

# %%
df.drop('Other', axis = 1,level = 1)
# Out:
#      Kitchen Remodels       Bath Remodels       Room Additions               \
#                 Minor Major         Minor Major        Kitchen Bath Bedroom
# 1995             1670   446          1787   516            328  571     637
# 1997             1455   419          1565   561            259  488     536
# 1999             1178   548          1444   632             44  397     656
# 2001             1144   686          1452   760             44  403     608
# 2003             1282   644          1489   773             37  409     645
# 2005             1341   855          1524   971             49  452     653
# 2007             1349  1067          1556  1231             37  416     685
# 2009             1148   878          1378  1168             42  426     576
# 2011             1120   755          1469  1030             34  328     509
# 2013             1055   760          1350  1102             28  319     499
# ...

# %%
outside_set = set(outside)
for i in range(len(outside_set)):
    st = outside_set.pop()
    df[st].plot().set_title(st)

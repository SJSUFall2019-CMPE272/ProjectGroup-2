# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
raw_data = pd.read_csv('C:/Users/Adi/Desktop/SJSU/272/out/sanfranciscoca.csv')
data = raw_data.drop(10)
data
# Out:
#    year  Attic Insulation (fiberglass) | Midrange  \
# 0  2008                                     108.6
# 1  2009                                     102.6
# 2  2010                                     104.6
# 3  2011                                     101.6
# 4  2013                                     113.5
# 5  2014                                     135.2
# 6  2015                                     133.0
# 7  2016                                     115.3
# 8  2017                                     179.4
# 9  2018                                       NaN
#
#    Backup Power Generator | Midrange  Backyard Patio | Midrange  \
# 0                               75.3                        NaN
# 1                               53.1                        NaN
# 2                               46.2                        NaN
# 3                               46.4                        NaN
# 4                               60.8                        NaN
# 5                               92.9                        NaN
# 6                               88.9                        NaN
# 7                               74.6                        NaN
# 8                               78.7                       88.0
# 9                                NaN                       70.9
#
#    Basement Remodel | Midrange  Bathroom Addition | Midrange  \
# 0                        101.2                          92.4
# 1                         97.2                          80.6
# 2                        107.1                          81.0
# 3                         85.0                          75.9
# 4                        105.2                          89.2
# 5                        117.8                         111.1
# 6                        124.4                         101.2
# 7                        122.2                          90.1
# 8                        117.1                          83.0
# 9                          NaN                         100.4
#
#    Bathroom Addition | Upscale  Bathroom Remodel | Midrange  \
# 0                         88.8                        114.1
# 1                         75.1                         95.2
# 2                         79.8                        101.9
# 3                         77.9                         93.3
# 4                         86.4                        118.8
# 5                         99.2                        136.5
# 6                         97.7                        119.9
# 7                         94.0                        102.0
# 8                         98.0                        110.0
# 9                         98.5                        121.3
#
#    Bathroom Remodel | Upscale  Deck Addition (composite) | Midrange  ...  \
# 0                        89.8                                 110.1  ...
# 1                        78.1                                  92.7  ...
# 2                        74.4                                 101.9  ...
# 3                        85.5                                  84.1  ...
# 4                        95.8                                 102.6  ...
# 5                       118.2                                 126.2  ...
# 6                        95.7                                 114.4  ...
# 7                        91.4                                  96.3  ...
# 8                        94.9                                 111.8  ...
# 9                        94.5                                 108.4  ...
#
#    Siding Replacement (fiber-cement) | Upscale  \
# 0                                        112.8
# 1                                         95.0
# 2                                        103.1
# 3                                         90.9
# 4                                         95.2
# 5                                        129.2
# 6                                        128.9
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
#
#    Siding Replacement (foam-backed vinyl) | Upscale  \
# 0                                              92.7
# 1                                              83.4
# 2                                              73.3
# 3                                              66.4
# 4                                              91.0
# 5                                             112.4
# 6                                              95.0
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
#
#    Siding Replacement (vinyl) | Midrange  Siding Replacement | Midrange  \
# 0                                    NaN                           96.3
# 1                                   88.0                            NaN
# 2                                   74.4                            NaN
# 3                                   73.0                            NaN
# 4                                   92.6                            NaN
# 5                                  109.8                            NaN
# 6                                   96.9                            NaN
# 7                                    NaN                           93.1
# 8                                    NaN                          107.1
# 9                                    NaN                          112.6
#
#    Sunroom Addition | Midrange  Two-Story Addition | Midrange  \
# 0                         67.7                           98.1
# 1                         66.1                           87.6
# 2                         67.8                           96.1
# 3                         62.6                           87.6
# 4                         60.2                           98.0
# 5                         84.6                          113.1
# 6                         87.6                           98.6
# 7                          NaN                          116.7
# 8                          NaN                          131.6
# 9                          NaN                            NaN
#
#    Window Replacement (vinyl) | Midrange  \
# 0                                  101.6
# 1                                  104.3
# 2                                   93.3
# 3                                   94.8
# 4                                  108.5
# 5                                  120.1
# 6                                  106.0
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#    Window Replacement (vinyl) | Upscale  Window Replacement (wood) | Midrange  \
# 0                                 100.5                                 108.9
# 1                                  99.6                                 104.5
# 2                                  92.8                                 104.5
# 3                                  92.5                                 101.5
# 4                                 110.2                                 121.3
# 5                                 127.2                                 133.8
# 6                                 113.5                                 119.8
# 7                                 113.1                                   NaN
# 8                                 112.0                                   NaN
# 9                                 118.0                                   NaN
#
#    Window Replacement (wood) | Upscale
# 0                                105.4
# 1                                104.4
# 2                                 94.0
# 3                                 93.1
# 4                                113.5
# 5                                123.8
# 6                                116.1
# 7                                111.0
# 8                                121.0
# 9                                122.7
#
# [10 rows x 39 columns]

# %%
import datetime
Year = []
for i in data.year:
    Year.append(datetime.datetime(i,1,1))
data['Year'] = Year
data.drop(columns=['year'],inplace = True)
data.set_index('Year', inplace=True)
data
# Out:
#             Attic Insulation (fiberglass) | Midrange  \
# Year
# 2008-01-01                                     108.6
# 2009-01-01                                     102.6
# 2010-01-01                                     104.6
# 2011-01-01                                     101.6
# 2013-01-01                                     113.5
# 2014-01-01                                     135.2
# 2015-01-01                                     133.0
# 2016-01-01                                     115.3
# 2017-01-01                                     179.4
# 2018-01-01                                       NaN
#
#             Backup Power Generator | Midrange  Backyard Patio | Midrange  \
# Year
# 2008-01-01                               75.3                        NaN
# 2009-01-01                               53.1                        NaN
# 2010-01-01                               46.2                        NaN
# 2011-01-01                               46.4                        NaN
# 2013-01-01                               60.8                        NaN
# 2014-01-01                               92.9                        NaN
# 2015-01-01                               88.9                        NaN
# 2016-01-01                               74.6                        NaN
# 2017-01-01                               78.7                       88.0
# 2018-01-01                                NaN                       70.9
#
#             Basement Remodel | Midrange  Bathroom Addition | Midrange  \
# Year
# 2008-01-01                        101.2                          92.4
# 2009-01-01                         97.2                          80.6
# 2010-01-01                        107.1                          81.0
# 2011-01-01                         85.0                          75.9
# 2013-01-01                        105.2                          89.2
# 2014-01-01                        117.8                         111.1
# 2015-01-01                        124.4                         101.2
# 2016-01-01                        122.2                          90.1
# 2017-01-01                        117.1                          83.0
# 2018-01-01                          NaN                         100.4
#
#             Bathroom Addition | Upscale  Bathroom Remodel | Midrange  \
# Year
# 2008-01-01                         88.8                        114.1
# 2009-01-01                         75.1                         95.2
# 2010-01-01                         79.8                        101.9
# 2011-01-01                         77.9                         93.3
# 2013-01-01                         86.4                        118.8
# 2014-01-01                         99.2                        136.5
# 2015-01-01                         97.7                        119.9
# 2016-01-01                         94.0                        102.0
# 2017-01-01                         98.0                        110.0
# 2018-01-01                         98.5                        121.3
#
#             Bathroom Remodel | Upscale  Deck Addition (composite) | Midrange  \
# Year
# 2008-01-01                        89.8                                 110.1
# 2009-01-01                        78.1                                  92.7
# 2010-01-01                        74.4                                 101.9
# 2011-01-01                        85.5                                  84.1
# 2013-01-01                        95.8                                 102.6
# 2014-01-01                       118.2                                 126.2
# 2015-01-01                        95.7                                 114.4
# 2016-01-01                        91.4                                  96.3
# 2017-01-01                        94.9                                 111.8
# 2018-01-01                        94.5                                 108.4
#
#             Deck Addition (composite) | Upscale  ...  \
# Year                                             ...
# 2008-01-01                                 85.4  ...
# 2009-01-01                                 82.0  ...
# 2010-01-01                                 83.5  ...
# 2011-01-01                                 70.0  ...
# 2013-01-01                                 86.0  ...
# 2014-01-01                                118.4  ...
# 2015-01-01                                103.7  ...
# 2016-01-01                                 82.4  ...
# 2017-01-01                                 86.0  ...
# 2018-01-01                                  NaN  ...
#
#             Siding Replacement (fiber-cement) | Upscale  \
# Year
# 2008-01-01                                        112.8
# 2009-01-01                                         95.0
# 2010-01-01                                        103.1
# 2011-01-01                                         90.9
# 2013-01-01                                         95.2
# 2014-01-01                                        129.2
# 2015-01-01                                        128.9
# 2016-01-01                                          NaN
# 2017-01-01                                          NaN
# 2018-01-01                                          NaN
#
#             Siding Replacement (foam-backed vinyl) | Upscale  \
# Year
# 2008-01-01                                              92.7
# 2009-01-01                                              83.4
# 2010-01-01                                              73.3
# 2011-01-01                                              66.4
# 2013-01-01                                              91.0
# 2014-01-01                                             112.4
# 2015-01-01                                              95.0
# 2016-01-01                                               NaN
# 2017-01-01                                               NaN
# 2018-01-01                                               NaN
#
#             Siding Replacement (vinyl) | Midrange  \
# Year
# 2008-01-01                                    NaN
# 2009-01-01                                   88.0
# 2010-01-01                                   74.4
# 2011-01-01                                   73.0
# 2013-01-01                                   92.6
# 2014-01-01                                  109.8
# 2015-01-01                                   96.9
# 2016-01-01                                    NaN
# 2017-01-01                                    NaN
# 2018-01-01                                    NaN
#
#             Siding Replacement | Midrange  Sunroom Addition | Midrange  \
# Year
# 2008-01-01                           96.3                         67.7
# 2009-01-01                            NaN                         66.1
# 2010-01-01                            NaN                         67.8
# 2011-01-01                            NaN                         62.6
# 2013-01-01                            NaN                         60.2
# 2014-01-01                            NaN                         84.6
# 2015-01-01                            NaN                         87.6
# 2016-01-01                           93.1                          NaN
# 2017-01-01                          107.1                          NaN
# 2018-01-01                          112.6                          NaN
#
#             Two-Story Addition | Midrange  \
# Year
# 2008-01-01                           98.1
# 2009-01-01                           87.6
# 2010-01-01                           96.1
# 2011-01-01                           87.6
# 2013-01-01                           98.0
# 2014-01-01                          113.1
# 2015-01-01                           98.6
# 2016-01-01                          116.7
# 2017-01-01                          131.6
# 2018-01-01                            NaN
#
#             Window Replacement (vinyl) | Midrange  \
# Year
# 2008-01-01                                  101.6
# 2009-01-01                                  104.3
# 2010-01-01                                   93.3
# 2011-01-01                                   94.8
# 2013-01-01                                  108.5
# 2014-01-01                                  120.1
# 2015-01-01                                  106.0
# 2016-01-01                                    NaN
# 2017-01-01                                    NaN
# 2018-01-01                                    NaN
#
#             Window Replacement (vinyl) | Upscale  \
# Year
# 2008-01-01                                 100.5
# 2009-01-01                                  99.6
# 2010-01-01                                  92.8
# 2011-01-01                                  92.5
# 2013-01-01                                 110.2
# 2014-01-01                                 127.2
# 2015-01-01                                 113.5
# 2016-01-01                                 113.1
# 2017-01-01                                 112.0
# 2018-01-01                                 118.0
#
#             Window Replacement (wood) | Midrange  \
# Year
# 2008-01-01                                 108.9
# 2009-01-01                                 104.5
# 2010-01-01                                 104.5
# 2011-01-01                                 101.5
# 2013-01-01                                 121.3
# 2014-01-01                                 133.8
# 2015-01-01                                 119.8
# 2016-01-01                                   NaN
# 2017-01-01                                   NaN
# 2018-01-01                                   NaN
#
#             Window Replacement (wood) | Upscale
# Year
# 2008-01-01                                105.4
# 2009-01-01                                104.4
# 2010-01-01                                 94.0
# 2011-01-01                                 93.1
# 2013-01-01                                113.5
# 2014-01-01                                123.8
# 2015-01-01                                116.1
# 2016-01-01                                111.0
# 2017-01-01                                121.0
# 2018-01-01                                122.7
#
# [10 rows x 38 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01',
#                '2017-01-01', '2018-01-01'],
#               dtype='datetime64[ns]', name='Year', freq=None)

# %%
columns = data.columns

# %%
from statsmodels.tsa.ar_model import AR
new_series = []
for i in columns: 
    ts = data[i].dropna()
    if len(ts)<7:
        new_series.append(abs(data[i].mean())
        continue
    model = AR(ts)
    model_fit = model.fit(trend='nc')
    yhat = model_fit.predict(len(ts), len(ts))
    final = 0.0
    if yhat.get(10) != None:
        final = yhat.get(10)
    elif yhat.get(9) != None:
        final = yhat.get(9)
    elif yhat.get(8) != None:
        final = yhat.get(8)
    elif yhat.get(7) != None:
        final = yhat.get(7)
    else:
        final = 88888
        
    new_series.append(final)
data = data.append(pd.Series(new_series, index=data.columns ), ignore_index=True)
data.loc[10]
# Out:
# 79.45
# 165.23333333333332
# 89.11666666666667
# 102.275
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# Attic Insulation (fiberglass) | Midrange            128.066648
# Backup Power Generator | Midrange                    81.342738
# Backyard Patio | Midrange                            79.450000
# Basement Remodel | Midrange                         122.752103
# Bathroom Addition | Midrange                        109.578003
# Bathroom Addition | Upscale                         100.873103
# Bathroom Remodel | Midrange                         119.566641
# Bathroom Remodel | Upscale                           96.050996
# Deck Addition (composite) | Midrange                103.335481
# Deck Addition (composite) | Upscale                  84.930970
# Deck Addition (wood) | Midrange                     134.209087
# Entry Door Replacement (fiberglass) | Midrange      133.688934
# Entry Door Replacement (steel) | Midrange           127.425882
# Family Room Addition | Midrange                     133.085445
# Garage Addition | Midrange                          102.834633
# Garage Addition | Upscale                            81.798428
# Garage Door Replacement | Midrange                  163.096850
# Garage Door Replacement | Upscale                   200.562593
# Grand Entrance (fiberglass) | Upscale               130.008613
# Home Office Remodel | Midrange                       84.290126
# Major Kitchen Remodel | Midrange                     97.250497
# Major Kitchen Remodel | Upscale                      94.091990
# Manufactured Stone Veneer | Midrange                165.233333
# Master Suite Addition | Midrange                    105.353569
# Master Suite Addition | Upscale                     102.954074
# Minor Kitchen Remodel | Midrange                    135.121910
# Roofing Replacement | Midrange                      102.414805
# Roofing Replacement | Upscale                        99.845606
# Siding Replacement (fiber-cement) | Upscale         131.021415
# Siding Replacement (foam-backed vinyl) | Upscale     93.797973
# Siding Replacement (vinyl) | Midrange                89.116667
# Siding Replacement | Midrange                       102.275000
# Sunroom Addition | Midrange                          91.395360
# Two-Story Addition | Midrange                       134.997531
# Window Replacement (vinyl) | Midrange               106.213208
# Window Replacement (vinyl) | Upscale                123.243624
# Window Replacement (wood) | Midrange                121.144836
# Window Replacement (wood) | Upscale                 119.561464
# Name: 10, dtype: float64

# %%
data
# Out:
#     Attic Insulation (fiberglass) | Midrange  \
# 0                                 108.600000
# 1                                 102.600000
# 2                                 104.600000
# 3                                 101.600000
# 4                                 113.500000
# 5                                 135.200000
# 6                                 133.000000
# 7                                 115.300000
# 8                                 179.400000
# 9                                        NaN
# 10                                128.066648
#
#     Backup Power Generator | Midrange Backyard Patio | Midrange  \
# 0                           75.300000                       NaN
# 1                           53.100000                       NaN
# 2                           46.200000                       NaN
# 3                           46.400000                       NaN
# 4                           60.800000                       NaN
# 5                           92.900000                       NaN
# 6                           88.900000                       NaN
# 7                           74.600000                       NaN
# 8                           78.700000                        88
# 9                                 NaN                      70.9
# 10                          81.342738                       NaN
#
#     Basement Remodel | Midrange  Bathroom Addition | Midrange  \
# 0                    101.200000                     92.400000
# 1                     97.200000                     80.600000
# 2                    107.100000                     81.000000
# 3                     85.000000                     75.900000
# 4                    105.200000                     89.200000
# 5                    117.800000                    111.100000
# 6                    124.400000                    101.200000
# 7                    122.200000                     90.100000
# 8                    117.100000                     83.000000
# 9                           NaN                    100.400000
# 10                   122.752103                    109.578003
#
#     Bathroom Addition | Upscale  Bathroom Remodel | Midrange  \
# 0                     88.800000                   114.100000
# 1                     75.100000                    95.200000
# 2                     79.800000                   101.900000
# 3                     77.900000                    93.300000
# 4                     86.400000                   118.800000
# 5                     99.200000                   136.500000
# 6                     97.700000                   119.900000
# 7                     94.000000                   102.000000
# 8                     98.000000                   110.000000
# 9                     98.500000                   121.300000
# 10                   100.873103                   119.566641
#
#     Bathroom Remodel | Upscale  Deck Addition (composite) | Midrange  \
# 0                    89.800000                            110.100000
# 1                    78.100000                             92.700000
# 2                    74.400000                            101.900000
# 3                    85.500000                             84.100000
# 4                    95.800000                            102.600000
# 5                   118.200000                            126.200000
# 6                    95.700000                            114.400000
# 7                    91.400000                             96.300000
# 8                    94.900000                            111.800000
# 9                    94.500000                            108.400000
# 10                   96.050996                            103.335481
#
#     Deck Addition (composite) | Upscale  ...  \
# 0                              85.40000  ...
# 1                              82.00000  ...
# 2                              83.50000  ...
# 3                              70.00000  ...
# 4                              86.00000  ...
# 5                             118.40000  ...
# 6                             103.70000  ...
# 7                              82.40000  ...
# 8                              86.00000  ...
# 9                                   NaN  ...
# 10                             84.93097  ...
#
#     Siding Replacement (fiber-cement) | Upscale  \
# 0                                    112.800000
# 1                                     95.000000
# 2                                    103.100000
# 3                                     90.900000
# 4                                     95.200000
# 5                                    129.200000
# 6                                    128.900000
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                   131.021415
#
#     Siding Replacement (foam-backed vinyl) | Upscale  \
# 0                                          92.700000
# 1                                          83.400000
# 2                                          73.300000
# 3                                          66.400000
# 4                                          91.000000
# 5                                         112.400000
# 6                                          95.000000
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                         93.797973
#
#     Siding Replacement (vinyl) | Midrange  Siding Replacement | Midrange  \
# 0                                     NaN                           96.3
# 1                                      88                            NaN
# 2                                    74.4                            NaN
# 3                                      73                            NaN
# 4                                    92.6                            NaN
# 5                                   109.8                            NaN
# 6                                    96.9                            NaN
# 7                                     NaN                           93.1
# 8                                     NaN                          107.1
# 9                                     NaN                          112.6
# 10                                    NaN                            NaN
#
#     Sunroom Addition | Midrange  Two-Story Addition | Midrange  \
# 0                      67.70000                      98.100000
# 1                      66.10000                      87.600000
# 2                      67.80000                      96.100000
# 3                      62.60000                      87.600000
# 4                      60.20000                      98.000000
# 5                      84.60000                     113.100000
# 6                      87.60000                      98.600000
# 7                           NaN                     116.700000
# 8                           NaN                     131.600000
# 9                           NaN                            NaN
# 10                     91.39536                     134.997531
#
#     Window Replacement (vinyl) | Midrange  \
# 0                              101.600000
# 1                              104.300000
# 2                               93.300000
# 3                               94.800000
# 4                              108.500000
# 5                              120.100000
# 6                              106.000000
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                             106.213208
#
#     Window Replacement (vinyl) | Upscale  \
# 0                             100.500000
# 1                              99.600000
# 2                              92.800000
# 3                              92.500000
# 4                             110.200000
# 5                             127.200000
# 6                             113.500000
# 7                             113.100000
# 8                             112.000000
# 9                             118.000000
# 10                            123.243624
#
#     Window Replacement (wood) | Midrange  Window Replacement (wood) | Upscale
# 0                             108.900000                           105.400000
# 1                             104.500000                           104.400000
# 2                             104.500000                            94.000000
# 3                             101.500000                            93.100000
# 4                             121.300000                           113.500000
# 5                             133.800000                           123.800000
# 6                             119.800000                           116.100000
# 7                                    NaN                           111.000000
# 8                                    NaN                           121.000000
# 9                                    NaN                           122.700000
# 10                            121.144836                           119.561464
#
# [11 rows x 38 columns]

# %%
data.to_csv("final_sanfransisco.csv")

# %%
#plt.plot(ts)

fig = plt.figure()
plt.plot(ts)
fig.suptitle('Year vs Value Gain', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Value Gain', fontsize=12)
fig.savefig('test.jpg')

# %%
#define function for ADF test
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
adf_test(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -2.704569
# p-value                        0.073251
# #Lags Used                     3.000000
# Number of Observations Used    6.000000
# Critical Value (1%)           -5.354256
# Critical Value (5%)           -3.646238
# Critical Value (10%)          -2.901198
# dtype: float64

# %%
#define function for kpss test
from statsmodels.tsa.stattools import kpss
#define KPSS
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
        kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
kpss_test(ts)
# Out:
# Results of KPSS Test:
# Test Statistic           0.396976
# p-value                  0.078459
# Lags Used                7.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\stattools.py:1685: FutureWarning: The behavior of using lags=None will change in the next release. Currently lags=None is the same as lags='legacy', and so a sample-size lag length is used. After the next release, the default will change to be the same as lags='auto' which uses an automatic lag length selection method. To silence this warning, either use 'auto' or 'legacy'
#   warn(msg, FutureWarning)

# %% [markdown]
# # Types of Stationarity

# %% [markdown]
# **Strict Stationary**: A strict stationary series satisfies the mathematical definition of a stationary process. For a strict stationary series, the mean, variance and covariance are not the function of time. The aim is to convert a non-stationary series into a strict stationary series for making predictions.
# **Trend Stationary**: A series that has no unit root but exhibits a trend is referred to as a trend stationary series. Once the trend is removed, the resulting series will be strict stationary. The KPSS test classifies a series as stationary on the absence of unit root. This means that the series can be strict stationary or trend stationary.
# **Difference Stationary**: A time series that can be made strict stationary by differencing falls under difference stationary. ADF test is also known as a difference stationarity test.
#
# Case 1: Both tests conclude that the series is not stationary -> series is not stationary
# Case 2: Both tests conclude that the series is stationary -> series is stationary
# **Case 3: KPSS = stationary and ADF = not stationary  -> trend stationary, remove the trend to make series strict stationary**
# Case 4: KPSS = not stationary and ADF = stationary -> difference stationary, use differencing to make series stationary

# %% [markdown]
# ## Differencing

# %%
ts_diff = ts - ts.shift(1)

# %% [markdown]
# ## Log Transformation

# %%
ts_log = np.log(ts)
ts_log_diff = ts_log - ts_log.shift(1)\

# %% [markdown]
# ## Transformation

# %%
ts_log = np.log(ts)

# %%
ts_log_diff = ts_log - ts_log.shift()

# %% [markdown]
# ## AR Model

# %%
from statsmodels.tsa.ar_model import AR
# contrived dataset
data = ts
# fit model
model = AR(data)
model_fit = model.fit()
# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# 10    119.561413
# dtype: float64
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %% [markdown]
# # MA Model

# %%
# MA example
from statsmodels.tsa.arima_model import ARMA
# contrived dataset
data = ts
# fit model
model = ARMA(data, order=(0, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# 10    113.510001
# dtype: float64
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %% [markdown]
# # ARMA Model

# %%
# ARIMA example
from statsmodels.tsa.arima_model import ARIMA
# contrived dataset
data = ts
# fit model
model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(data), len(data), typ='levels')
print(yhat)
# Out:
# 9    117.938129
# dtype: float64
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\ar_model.py:763: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.sigma2) + (1 + self.df_model) * np.log(nobs)/nobs
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %% [markdown]
# # SARIMA Model

# %%
# SARIMA example
from statsmodels.tsa.statespace.sarimax import SARIMAX
# contrived dataset
data = ts
# fit model
model = SARIMAX(data, order=(1, 1, 1), seasonal_order=(1, 1, 1, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 10    124.359338
# dtype: float64
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

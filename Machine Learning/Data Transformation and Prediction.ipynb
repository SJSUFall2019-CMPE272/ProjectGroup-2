# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import datetime
from statsmodels.tsa.ar_model import AR
# %matplotlib inline

# %%
import glob, os
os.chdir(f"C:/Users/Adi/Desktop/SJSU/272/out_and/")
for file in glob.glob("*.csv"):
    raw_data = pd.read_csv(f"C:/Users/Adi/Desktop/SJSU/272/out_and/{file}")

    will_stay,will_not_stay = 'Attic Bedroom Remodel | Midrange','Attic Insulation (fiberglass) | Midrange'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Backyard Patio | Midrange','Backyard Patio'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Bathroom Remodel | Midrange','Bath Remodel | Midrange'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    if 'Bath Remodel | Universal Design' in raw_data.columns:
        del raw_data['Bath Remodel | Universal Design']

    will_stay,will_not_stay = 'Bathroom Remodel | Upscale','Bath Remodel | Upscale'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Deck Addition (composite) | Upscale','Deck Addition | Composite'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Deck Addition (wood) | Midrange','Deck Addition | Wood'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Entry Door Replacement (steel) | Midrange','Entry Door Replacement (steel) | Midrange*'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Entry Door Replacement (steel) | Midrange','Entry Door Replacement | Steel'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Grand Entrance (fiberglass) | Upscale','Grand Entrance | Fiberglass'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Grand Entrance (fiberglass) | Upscale','Grand Entrance | Upscale'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Garage Door Replacement | Upscale','Garage Door Replacement'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Manufactured Stone Veneer | Midrange','Manufactured Stone Veneer'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Manufactured Stone Veneer | Midrange','Stone Veneer Accent | Midrange'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Roofing Replacement | Upscale','Roofing Replacement | Metal'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Roofing Replacement | Midrange','Roofing Replacement | Asphalt Shingles'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Siding Replacement (vinyl) | Midrange','Siding Replacement | Midrange'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Siding Replacement (vinyl) | Midrange','Siding Replacement'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    if 'Universal Design Bathroom | Upscale' in raw_data.columns:
        del raw_data['Universal Design Bathroom | Upscale']

    if 'Universal Design Bathroom | Midrange' in raw_data.columns:
        del raw_data['Universal Design Bathroom | Midrange']

    will_stay,will_not_stay = 'Window Replacement (vinyl) | Upscale','Window Replacement | Vinyl'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    will_stay,will_not_stay = 'Window Replacement (wood) | Midrange','Window Replacement | Wood'
    if (will_stay in raw_data.columns) and (will_not_stay in raw_data.columns):
        raw_data[will_stay].fillna(raw_data[will_not_stay], inplace=True)
        del raw_data[will_not_stay]

    raw_data.to_csv(f"C:/Users/Adi/Desktop/SJSU/272/out_final/{file}")
    data = raw_data
    Year = []
    for i in data.year:
        Year.append(datetime.datetime(i,1,1))
    data['Year'] = Year
    data.drop(columns=['year'],inplace = True)
    data.set_index('Year', inplace=True)

    columns = data.columns

    new_series = []
    for i in columns:
        ts = data[i].dropna()
        if len(ts)<7:
            new_series.append(abs(data[i].mean()))
            continue
        model = AR(ts)
        model_fit = model.fit(trend='nc')
        yhat = model_fit.predict(len(ts), len(ts))
        final = 0.0
        if yhat.get(11) != None:
            final = yhat.get(11)
        elif yhat.get(10) != None:
            final = yhat.get(10)
        elif yhat.get(9) != None:
            final = yhat.get(9)
        elif yhat.get(8) != None:
            final = yhat.get(8)
        elif yhat.get(7) != None:
            final = yhat.get(7)
        else:
            final = 88888

        new_series.append(abs(final))

    data = data.append(pd.Series(new_series, index=data.columns ), ignore_index=True)
    data.to_csv(f"C:/Users/Adi/Desktop/SJSU/272/prediction/{file}")
    data.loc[11].to_csv(f"C:/Users/Adi/Desktop/SJSU/272/only_prediction/{file}")
    data.T.sort_values(11, ascending=False).head(5).T.loc[11].to_csv(f"C:/Users/Adi/Desktop/SJSU/272/top_five_prediction/{file}")
# Out:
# C:\Users\Adi\Anaconda4\lib\site-packages\ipykernel_launcher.py:148: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\Adi\Anaconda4\lib\site-packages\ipykernel_launcher.py:149: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\Adi\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...
